# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"
shark_dt = pd.read_excel(url)

# %%
shark_dt
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-06-17 00:00:00  2025.0  Unprovoked                 USA
# 1     2025-06-11 00:00:00  2025.0  Unprovoked                 USA
# 2     2025-05-29 00:00:00  2025.0  Unprovoked                 USA
# 3     2025-05-26 00:00:00  2025.0  Unprovoked             Vanuatu
# 4     2025-05-15 00:00:00  2025.0  Unprovoked           Australia
# ...                   ...     ...         ...                 ...
# 7015          Before 1903     0.0  Unprovoked           AUSTRALIA
# 7016          Before 1903     0.0  Unprovoked           AUSTRALIA
# 7017            1900-1905     0.0  Unprovoked                 USA
# 7018            1883-1889     0.0  Unprovoked              PANAMA
# 7019            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   State                             Location      Activity  \
# 0        South Carolina                 Hilton Head Island        Swimming
# ...

# %%
shark_dt.head()
# Out:
#                   Date    Year        Type    Country            State  \
# 0  2025-06-17 00:00:00  2025.0  Unprovoked        USA   South Carolina
# 1  2025-06-11 00:00:00  2025.0  Unprovoked        USA          Florida
# 2  2025-05-29 00:00:00  2025.0  Unprovoked        USA   North Carolina
# 3  2025-05-26 00:00:00  2025.0  Unprovoked    Vanuatu      South Santo
# 4  2025-05-15 00:00:00  2025.0  Unprovoked  Australia  South Australia
#
#                Location    Activity            Name Sex Age  ...    Species   \
# 0  Hilton Head Island      Swimming      Not stated   F  12  ...  Not stated
# 1           Boca Grande  Snorkeling     Leah Lendel   F   9  ...  Bull shark
# 2          Sunset Beach    Swimming     Sean Barton   M  26  ...  Not stated
# 3  Espiitu Santo Island    Swimming           Tumas   M  14  ...  Not stated
# 4        Port Noarlunga    Swimming  Richard Vinall   M  66  ...  Not stated
#
# ...

# %%
shark_dt.tail()
# Out:
#              Date  Year        Type             Country              State  \
# 7015  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7016  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7017    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 7018    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 7019    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 7015                          Roebuck Bay        Diving
# 7016                                  NaN  Pearl diving
# 7017                       Ocracoke Inlet      Swimming
# 7018                 Panama Bay 8ºN, 79ºW           NaN
# 7019  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  ... Species   \
# 7015                   male   M  NaN  ...      NaN
# 7016                  Ahmun   M  NaN  ...      NaN
# ...

# %%
shark_dt.value_counts("Species")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 shark_dt.value_counts("Species")
#
# File f:\anaconda3\Lib\site-packages\pandas\core\frame.py:7509, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7506     subset = self.columns.tolist()
#    7508 name = "proportion" if normalize else "count"
# -> 7509 counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510 counts.name = name
#    7512 if sort:
#
# File f:\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
# ...

# %%
shark_dt.value_counts("Type")
# Out:
# Type
# Unprovoked             5176
# Provoked                637
# Invalid                 552
# Watercraft              355
# Sea Disaster            242
# Questionable             26
# Boat                      7
#  Provoked                 2
# ?                         1
# Unconfirmed               1
# Under investigation       1
# Unverified                1
# unprovoked                1
# Name: count, dtype: int64

# %%
shark_dt.shape
# Out:
# (7020, 23)

# %%
shark_dt.describe()
# Out:
#               Year  original order
# count  7018.000000     6799.000000
# mean   1935.373611     3401.152081
# std     271.597394     1963.076319
# min       0.000000        2.000000
# 25%    1947.250000     1701.500000
# 50%    1986.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2026.000000     6802.000000

# %%
shark_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7020 entries, 0 to 7019
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7020 non-null   object
#  1   Year            7018 non-null   float64
#  2   Type            7002 non-null   object
#  3   Country         6970 non-null   object
#  4   State           6535 non-null   object
#  5   Location        6454 non-null   object
#  6   Activity        6435 non-null   object
#  7   Name            6801 non-null   object
#  8   Sex             6441 non-null   object
#  9   Age             4026 non-null   object
#  10  Injury          6985 non-null   object
#  11  Fatal Y/N       6459 non-null   object
#  12  Time            3494 non-null   object
#  13  Species         3889 non-null   object
#  14  Source          7001 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   object
# ...

# %%
shark_dt
# Out:
#                      Date                          Year        Type  \
# 0     2025-06-17 00:00:00 1970-01-01 00:00:00.000002025  Unprovoked
# 1     2025-06-11 00:00:00 1970-01-01 00:00:00.000002025  Unprovoked
# 2     2025-05-29 00:00:00 1970-01-01 00:00:00.000002025  Unprovoked
# 3     2025-05-26 00:00:00 1970-01-01 00:00:00.000002025  Unprovoked
# 4     2025-05-15 00:00:00 1970-01-01 00:00:00.000002025  Unprovoked
# ...                   ...                           ...         ...
# 7015          Before 1903 1970-01-01 00:00:00.000000000  Unprovoked
# 7016          Before 1903 1970-01-01 00:00:00.000000000  Unprovoked
# 7017            1900-1905 1970-01-01 00:00:00.000000000  Unprovoked
# 7018            1883-1889 1970-01-01 00:00:00.000000000  Unprovoked
# 7019            1845-1853 1970-01-01 00:00:00.000000000  Unprovoked
#
#                  Country              State  \
# 0                    USA     South Carolina
# 1                    USA            Florida
# ...

# %%
shark_dt = pd.read_excel("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
shark_dt_2020 = shark_dt[shark_dt["Year"] >= 2020]
shark_dt_2020['Year'].value_counts().sort_index()
# Out:
# Year
# 2020.0    101
# 2021.0    109
# 2022.0     98
# 2023.0    109
# 2024.0     51
# 2025.0     29
# 2026.0      1
# Name: count, dtype: int64
